# %%
import dlib

# %%
training_options = dlib.simple_object_detector_training_options()
training_options.add_left_right_image_flips = True

#hiperparametro de custo para o SVM
training_options.C = 5
training_options.be_verbose = True

# %%
dlib.train_simple_object_detector("data/relogios_treino.xml", "data/clock_detector.svm", training_options)
# Out:
# Training with C: 5
# Training with epsilon: 0.01
# Training using 4 threads.
# Training with sliding window 81 pixels wide by 79 pixels tall.
# Training on both left and right flipped versions of images.
# objective:     140.866
# objective gap: 140.86
# risk:          28.1721
# risk gap:      28.1721
# num planes:    3
# iter:          1
#
# objective:     46.3972
# objective gap: 46.32
# risk:          9.26403
# risk gap:      9.26399
# num planes:    4
# iter:          2
#
# objective:     38.8145
# objective gap: 38.6563
# risk:          7.73131
# risk gap:      7.73126
# num planes:    5
# iter:          3
#
# objective:     25.065
# objective gap: 24.8376
# risk:          4.96759
# risk gap:      4.96751
# num planes:    6
# iter:          4
#
# objective:     27.0885
# objective gap: 26.7941
# risk:          5.35891
# risk gap:      5.35883
# num planes:    7
# iter:          5
#
# objective:     12.4409
# objective gap: 12.1225
# risk:          2.4246
# ...
